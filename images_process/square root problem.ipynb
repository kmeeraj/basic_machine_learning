# %%
# find out the square root of a number
# 9 = 3

# %%
#randon guess x = y /2 , square of 9 is 4.5 
# 9 , the sqaure of the number is less than half of the value
input = 9

# %%
guess = input/2

# %%
guess
# Out:
# 4.5

# %%
#TEST WHETHER value is correct 
# guess ^ 2 = input

# %%
output = guess**2

# %%
output
# Out:
# 20.25

# %%
error = output - input
error
# Out:
# 11.25

# %%
input = 9
guess = input/2
for i in range (100):
    guess = guess - 0.05
    output = guess**2
    print (output)
    error = output - input
    print (error)
# Out:
# 19.802500000000002
# 10.802500000000002
# 19.360000000000003
# 10.360000000000003
# 18.922500000000003
# 9.922500000000003
# 18.490000000000006
# 9.490000000000006
# 18.062500000000007
# 9.062500000000007
# 17.640000000000008
# 8.640000000000008
# 17.22250000000001
# 8.22250000000001
# 16.810000000000013
# 7.810000000000013
# 16.402500000000014
# 7.402500000000014
# 16.000000000000014
# 7.000000000000014
# 15.602500000000015
# 6.602500000000015
# 15.210000000000017
# 6.210000000000017
# 14.822500000000018
# 5.8225000000000176
# 14.440000000000019
# 5.440000000000019
# 14.06250000000002
# 5.0625000000000195
# 13.69000000000002
# 4.690000000000021
# 13.322500000000023
# 4.322500000000023
# 12.960000000000022
# 3.960000000000022
# 12.602500000000024
# 3.602500000000024
# 12.250000000000025
# 3.250000000000025
# 11.902500000000027
# 2.9025000000000265
# 11.560000000000027
# 2.560000000000027
# 11.222500000000027
# 2.222500000000027
# 10.890000000000029
# 1.890000000000029
# ...
